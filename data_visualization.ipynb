# %%
# %matplotlib inline

import pandas as pd
from sklearn.datasets import load_digits
import hypertools as hyp

# %%
df = pd.read_csv('main_cluster.csv')
# Subset the column of the clustering result
target = df['clustering']
df = df.drop('clustering', axis=1)
group = target.astype('str')

# %%
hyp.plot(df, '.', group=group, model='TSNE', ndims=2, legend=[1,2,3,4,5], title = "2D Representation of the Main Cluster using t-SNE")
# Out:
# (<matplotlib.figure.Figure at 0x10f414950>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10f3850d0>,
#  [array([[ 19.28615379, -12.87709618],
#          [ 11.18796921, -25.90093422],
#          [ 15.81884193, -14.44791031],
#          ...,
#          [ 17.84023094, -11.22028255],
#          [ 12.12007999,   8.36201   ],
#          [  8.31546974, -17.23242569]], dtype=float32)],
#  None)

# %%
hyp.plot(df, '.', group=group, model='PCA', ndims=2, legend=[1,2,3,4,5], title = "2D Representation of the Main Cluster using PCA")
# Out:
# (<matplotlib.figure.Figure at 0x11c173e90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11c02c050>,
#  [array([[ 0.72128723,  0.05671199],
#          [ 0.5434421 ,  0.30673736],
#          [ 0.66563727,  0.08602746],
#          ...,
#          [ 0.64635947,  0.01351535],
#          [ 0.1710799 , -0.39744988],
#          [ 0.54281358,  0.19088799]])],
#  None)

# %%
hyp.plot(df, '.', group=group, model='TSNE', ndims=3, legend=[1,2,3,4,5], title = "3D Representation of the Main Cluster using t-SNE")
# Out:
# (<matplotlib.figure.Figure at 0x11c2a72d0>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x1147bd290>,
#  [array([[   9.62216377, -106.05560303,   -8.70253658],
#          [  -5.94893026,  -56.84489059,   32.25551987],
#          [ -17.79373741,  118.55084229,   58.52999878],
#          ...,
#          [  74.59817505,   21.78234673,  -35.17802811],
#          [  28.38561058,  -10.271348  ,  -85.03614044],
#          [  58.81373215,  -29.40696335,   -2.62560844]], dtype=float32)],
#  None)

# %%
df = pd.read_csv('cluster_3.csv')
# Subset the column of the clustering result
target = df['clustering']
df = df.drop('clustering', axis=1)
group = target.astype('str')

# %%
hyp.plot(df, '.' ,group=group, model='TSNE', ndims=2, legend=[1,2,3,4], title = "2D Representation of Cluster 3 Using t-SNE")
# Out:
# (<matplotlib.figure.Figure at 0x10f41f690>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11c1733d0>,
#  [array([[ -57.24398422,  -65.45613098],
#          [  -5.88417721,   12.53938198],
#          [  18.03806305,  -18.33631897],
#          [  74.48269653,   -8.24193096],
#          [ -63.30307007,   87.07228088],
#          [ -10.46864128,  -51.06181335],
#          [ -54.65112686,  -32.78926468],
#          [ 104.75585175,   53.16719055],
#          [-154.0112915 ,   -7.17145777],
#          [ -35.55291367,    4.64542437],
#          [ 122.37464905,   31.32344055],
#          [ -37.96005249,   70.23668671],
#          [ -69.74534607,   26.08940887],
#          [ -99.73704529,   27.29267693],
#          [  34.28600311,   -5.45150709],
#          [  90.89629364,   34.14806366],
#          [  31.66564178,  -53.41983795],
#          [ -31.41249657,  -30.43658638],
#          [ -55.30141449,   -4.03383303],
#          [  34.79283524,  -30.05323029],
#          [   1.11780167,   -7.46470642],
#          [ -55.70862961,   52.88411713],
#          [ -74.13265991,  -12.01376915],
#          [  36.01537704,   39.95080185],
#          [ -95.06667328,  -39.22706604],
#          [ -98.06797028,  -62.77209854],
#          [-149.68737793,   10.25629044],
#          [  17.38657188,    8.03277016],
#          [ 103.69309235,   15.17888546],
#          [ -73.79605103,  -91.87511444],
#          [ -32.55424118,  -95.81699371],
#          [ -48.51319122,   21.32407379],
#          [-147.28103638,  -71.42327118],
#          [ -75.45661163,  -34.67394257],
#          [  -5.78396368,  -29.01489449],
#          [ 146.61480713,   21.44780731],
#          [-125.93162537,  -71.67292023],
#          [  69.53242493,   52.46178818],
#          [  99.12916565,   -9.14988613],
#          [ -22.25675774,  -14.19190884],
#          [ -23.77666855,   25.279356  ],
#          [-140.09761047,  -93.09170532],
#          [   8.46959209,   63.94825745],
#          [  81.82150269,   14.28690624],
#          [  36.65827942,   18.67382812],
#          [ 128.63235474,   69.35414124],
#          [  11.15382862,  -44.38185501],
#          [ -31.76886749,  -50.75722122],
#          [  65.28572083,  -34.55686569],
#          [ -78.63032532,   57.69879532],
#          [  55.03871536,    6.30028915],
#          [ -92.14863586,    4.22171307],
#          [  58.8788414 ,   27.71139336],
#          [   3.37781835,   32.58056259],
#          [-143.00183105,  -46.97494125],
#          [ -75.48377991,  -55.39444351],
#          [ 141.96252441,   54.92547989],
#          [  52.77417374,  -16.05014992],
#          [-114.23747253,  -24.771101  ],
#          [ 123.12339783,    1.46071064]], dtype=float32)],
#  None)

# %%
hyp.plot(df, '.' ,group=group, model='PCA', ndims=2, legend=[1,2,3,4], title = "2D Representation of Cluster 3 Using PCA")
# Out:
# (<matplotlib.figure.Figure at 0x11c1c4350>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11ca3f210>,
#  [array([[  5.05365209e-02,  -2.83958656e-01],
#          [  2.97673250e-04,   6.32768450e-03],
#          [ -8.78758474e-02,  -6.80850909e-03],
#          [ -1.96344690e-01,   1.05240767e-01],
#          [  4.84047135e-01,   7.00447909e-01],
#          [ -2.11830601e-02,  -8.55548338e-02],
#          [  1.43044794e-01,  -1.90072185e-01],
#          [ -4.31963683e-01,   1.61823294e-01],
#          [  2.12588763e-01,  -2.16050594e-01],
#          [  9.88326461e-02,  -9.59302812e-02],
#          [ -3.06635857e-01,   3.19105806e-02],
#          [  1.24573987e-01,   3.88641742e-01],
#          [  3.14656537e-01,  -5.20395548e-02],
#          [  1.64298775e-01,   2.10287242e-03],
#          [ -1.40362367e-01,  -2.02031126e-02],
#          [ -3.09187383e-01,   1.19132434e-01],
#          [ -1.20159853e-01,  -6.38344998e-02],
#          [ -4.23541540e-04,  -1.03183275e-01],
#          [  1.49322144e-01,  -1.75049504e-01],
#          [ -8.78758474e-02,  -6.80850909e-03],
#          [ -5.80413030e-02,  -4.06397726e-02],
#          [  2.81231029e-01,   1.72955821e-01],
#          [  1.55669616e-01,  -2.29364097e-01],
#          [ -1.25520622e-01,   6.17902606e-02],
#          [  1.58164597e-02,  -2.59095368e-01],
#          [  1.16088908e-01,  -2.21105719e-01],
#          [  1.76917252e-01,  -2.52910555e-01],
#          [ -8.79829931e-02,  -1.91939178e-02],
#          [ -3.09187383e-01,   1.19132434e-01],
#          [ -1.37020382e-01,  -2.81930704e-01],
#          [  5.62112183e-01,   2.46083359e-01],
#          [  1.78683398e-01,  -1.32709148e-01],
#          [  3.44824096e-01,   1.07056026e-01],
#          [  6.29599416e-02,  -2.65808897e-01],
#          [ -4.82955263e-02,  -1.05031933e-01],
#          [ -1.66486908e-01,   2.08942848e-01],
#          [  1.71764574e-01,   3.19032144e-02],
#          [ -2.25146208e-01,   1.74419164e-01],
#          [ -2.87395405e-01,   7.03059175e-02],
#          [ -2.59730005e-02,  -1.31171766e-01],
#          [  7.71646161e-02,  -1.52427753e-02],
#          [  4.20851223e-01,   6.42194485e-02],
#          [  2.31677178e-02,   1.46351478e-01],
#          [ -2.91970804e-01,   1.29085983e-01],
#          [ -1.20743587e-01,   6.21441574e-02],
#          [ -3.19208648e-01,   1.49760919e-01],
#          [ -8.83350563e-02,  -7.82622612e-02],
#          [ -1.59443612e-03,  -1.20013775e-01],
#          [ -1.05509065e-01,   8.54323093e-02],
#          [  4.93579929e-01,   1.54267823e-01],
#          [ -1.45233139e-01,   5.16922917e-02],
#          [  1.83786458e-01,  -7.96949643e-02],
#          [ -1.62028831e-01,   7.24197041e-02],
#          [ -2.04288062e-03,  -9.75660730e-03],
#          [  2.32747957e-01,   9.25478212e-02],
#          [  9.93696990e-02,  -2.73156244e-01],
#          [ -3.19208648e-01,   1.49760919e-01],
#          [ -1.04795999e-01,   6.29441129e-02],
#          [ -9.00404917e-02,  -2.45351476e-01],
#          [ -4.15160587e-01,   1.31090200e-01]])],
#  None)

# %%
hyp.plot(df, '.', group=group, model='TSNE', ndims=3, legend=[1,2,3,4], title = "3D Representation of Cluster 3 Using t-SNE")
# Out:
# (<matplotlib.figure.Figure at 0x11ca54510>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x11ca5b550>,
#  [array([[  2.45194798e+01,   2.45926270e+02,  -1.39145966e+02],
#          [ -9.20970058e+00,  -1.44939072e+02,  -6.64898376e+01],
#          [  2.38649811e+02,  -2.24049576e+02,   6.92142308e-01],
#          [ -9.85846043e+00,   1.22503807e+02,  -1.94489365e+02],
#          [ -7.06137878e+02,   3.58344666e+02,   5.56876526e+02],
#          [  6.91081924e+01,  -4.18192368e+01,  -3.39191093e+01],
#          [  1.41349457e+02,   2.73109375e+02,   7.96950073e+01],
#          [  2.70140808e+02,  -2.73122997e+01,   7.75995941e+01],
#          [  2.00207100e+01,   3.65522705e+02,  -7.53813904e+02],
#          [ -7.66382294e+01,   1.75680008e+01,   1.14821693e+02],
#          [ -7.90516510e+01,  -1.12431770e+02,   2.26468277e+02],
#          [ -6.73850479e+01,  -2.57259644e+02,  -1.82249603e+01],
#          [  9.50391617e+01,   9.77175522e+01,   6.96927109e+01],
#          [  2.31934448e+02,   8.79469604e+01,  -3.39265404e+01],
#          [  1.81295033e+01,  -3.69829226e+00,   2.25038712e+02],
#          [  2.35437897e+02,   1.49697657e+01,  -1.68395187e+02],
#          [  1.41270647e+01,  -1.18370314e+01,  -1.53308395e+02],
